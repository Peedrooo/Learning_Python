# %%
import pandas as pd 
import numpy as np 
from pathlib import Path
import os

# %%
data = pd.read_csv(str(Path(os.getcwd()).parent) + '\\data\\houses_to_rent.csv')

# %% [markdown]
# # Seletores

# %% [markdown]
# ## Head

# %%
aux = data.head(5)
aux.head(2)
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
#
#        furniture    hoa rent amount property tax fire insurance    total
# 0      furnished    R$0     R$8,000      R$1,000          R$121  R$9,121
# 1  not furnished  R$540       R$820        R$122           R$11  R$1,493

# %% [markdown]
# ## loc

# %%
aux = data.loc[5:10]
aux
# Out:
#     Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 5            5     1    13      1         1               0     2  acept
# 6            6     1    55      1         1               1     2  acept
# 7            7     1    55      2         2               1     2  acept
# 8            8     1    82      3         1               1     3  acept
# 9            9     1    32      1         1               1    16  acept
# 10          10     0    60      1         1               0     6  acept
#
#         furniture      hoa rent amount property tax fire insurance    total
# 5   not furnished      R$0     R$2,200         R$42           R$28  R$2,270
# 6       furnished  R$1,950     R$5,000        R$375           R$64  R$7,389
# 7   not furnished    R$600     R$1,300         R$67           R$17  R$1,984
# 8       furnished    R$828     R$2,000        R$109           R$26  R$2,963
# 9   not furnished    R$533     R$2,900          R$0           R$37  R$3,470
# ...

# %% [markdown]
# ## Samble

# %%
data.sample() # Pega uma amostra
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 5598        5598     1    65      2         1               0     -  acept
#
#           furniture  hoa rent amount property tax fire insurance    total
# 5598  not furnished  R$0     R$1,200         R$34           R$19  R$1,253

# %%
data.sample(n = 5) # Especificando quantidade
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 2188        2188     1    65      2         2               2    18
# 4644        4644     1   450      4         5               8     -
# 2274        2274     1   174      3         4               3    15
# 4312        4312     1   130      3         3               2     4
# 5665        5665     1    56      1         1               0     9
#
#          animal      furniture      hoa rent amount property tax  \
# 2188      acept      furnished    R$800     R$4,450          R$0
# 4644      acept  not furnished      R$0    R$10,120        R$618
# 2274  not acept  not furnished  R$2,500    R$10,400        R$817
# 4312  not acept      furnished  R$1,412     R$6,500        R$470
# 5665  not acept  not furnished    R$400     R$1,450          R$0
#
#      fire insurance     total
# 2188           R$18   R$5,268
# 4644          R$153  R$10,890
# 2274          R$132  R$13,850
# 4312           R$83   R$8,465
# ...

# %%
data.sample(n = 5, random_state = 52) # Especificando quantidade e localização
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 3836        3836     0   189      3         3               3    19
# 5355        5355     1    26      1         1               0     4
# 1623        1623     1    29      1         1               0     -
# 2260        2260     1   124      3         2               3     7
# 3340        3340     1    50      2         1               1     8
#
#          animal      furniture      hoa rent amount property tax  \
# 3836      acept  not furnished  R$1,000     R$9,800        R$506
# 5355      acept      furnished    R$400     R$4,300         R$60
# 1623  not acept  not furnished  Incluso     R$1,430          R$0
# 2260      acept  not furnished  R$1,450     R$6,600        R$300
# 3340      acept  not furnished    R$580     R$1,100        R$100
#
#      fire insurance     total
# 3836          R$125  R$11,430
# 5355           R$55   R$4,815
# 1623           R$19   R$1,449
# 2260           R$84   R$8,434
# ...

# %% [markdown]
# # Contador

# %% [markdown]
# ## Vale_count -> uso em valores categóricos

# %%
type(data.value_counts())
# Out:
# pandas.core.series.Series

# %%
data.furniture.value_counts()
# Out:
# not furnished    4498
# furnished        1582
# Name: furniture, dtype: int64
