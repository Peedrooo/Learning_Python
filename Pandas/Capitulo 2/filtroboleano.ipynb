# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Filtros Boleanos

# %%
# Operadores lógicos
# & - E
# | - OU
# ~ - NÃO

# %%
from pathlib import Path
import os

# %%
os
# Out:
# <module 'os' from 'C:\\Users\\pedro\\anaconda3\\envs\\machine\\lib\\os.py'>

# %%
data = pd.read_csv(str(Path(os.getcwd()).parent) + '\\data\\houses_to_rent.csv')

# %%
data.rooms > 2
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 6075    False
# 6076    False
# 6077    False
# 6078     True
# 6079    False
# Name: rooms, Length: 6080, dtype: bool

# %%
data["rooms"]> 2
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 6075    False
# 6076    False
# 6077    False
# 6078     True
# 6079    False
# Name: rooms, Length: 6080, dtype: bool

# %%
data.loc[data.rooms > 2]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 2              2     1   443      5         5               4     3
# 8              8     1    82      3         1               1     3
# 13            13     1   375      4         5               5     1
# 17            17     1   100      3         2               1     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6069        6069     1   114      3         2               3    14
# 6070        6070     1   200      4         5               3     2
# 6071        6071     0   600      5         5               4     -
# 6072        6072     1   200      4         4               4    21
# 6078        6078     1   160      3         2               2     -
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# ...

# %%
data[~(data.rooms > 2) & (data.area > 300)]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 67            67     1   345      2         3               2     4
# 195          195     1   400      2         5               4     -
# 1085        1085     1   500      2         2               1     -
# 1338        1338     1   380      2         4               0    21
# 1419        1419     1   310      2         6               3    11
# 1460        1460     1   440      1         2               4     -
# 1711        1711     1   330      2         4               3     -
# 1714        1714     1   305      2         3               0    10
# 1875        1875     1   830      2         2               2     -
# 2010        2010     1   418      2         4               3    17
# 2682        2682     1   340      2         4               3    14
# 3766        3766     0   350      2         2               2     -
# 4244        4244     1   330      2         3               2     -
# ...

# %%
filtro = ((data.rooms == 3) & (data.floor == "5")) | (data.area > 550)

# %%
data[filtro]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 41            41     1   800      4         5               4     9
# 44            44     0   650      5         4               8     -
# 63            63     1   750      7         6               5     -
# 180          180     1   170      3         2               2     5
# 226          226     1   122      3         4               3     5
# ...          ...   ...   ...    ...       ...             ...   ...
# 5908        5908     1   105      3         2               2     5
# 5941        5941     1   600      4         5               6     -
# 5968        5968     1   210      3         4               3     5
# 6045        6045     1   600      5         5               6     -
# 6071        6071     0   600      5         5               4     -
#
#          animal      furniture      hoa rent amount property tax  \
# 41        acept  not furnished  R$6,000    R$15,000      R$3,334
# ...
